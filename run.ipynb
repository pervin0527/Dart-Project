# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd drive/My\ Drive/Dart-Project
# !pwd
# !ls
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/Dart-Project'
# /content/drive/My Drive/Dart-Project
# /content/drive/My Drive/Dart-Project
# API_KEY.txt  Dart.py  input.csv  input.gsheet  main.py	output.xlsx  __pycache__  run.ipynb

# %%
# %run main.py
# Out:
# 크롤링을 시작합니다.
#
# ========== STEP 1 : Find corp_code ==========
# 삼성전자 found.
# 에코프로 found.
# ========== STEP 2 : Find report_code & financial statement subject. ==========
# 삼성전자 - 수익(매출액) found.
# 삼성전자 - 영업이익 found.
# 삼성전자 - 수익(매출액) found.
# 삼성전자 - 영업이익 found.
# 에코프로 - 영업이익 found.
# 에코프로 - 매출액 found.
# 에코프로 - 영업이익 found.
# 에코프로 - 매출액 found.
# ========== STEP 3 : find financial statements comment subjets ==========
# /usr/local/lib/python3.10/dist-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# 삼성전자 - 제품 및 재공품 등의 변동 found.
# 삼성전자 - 제품 및 재공품 등의 변동 found.
# ...
